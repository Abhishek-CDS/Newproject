# %%
#!pip install pymysql
#!pip install mysql-connector

# %%
import os
import mysql.connector
import pandas as pd
import numpy as np

import warnings 
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("Bank GoodCredit_Client_Project.csv")

# %%
data
# Out:
#          Unnamed: 0 dt_opened_x  customer_no upload_dt_x  acct_type  \
# 0                 0   10-Nov-15        12265   20-Oct-15          6
# 1                 1   10-Nov-15        12265   20-Oct-15          6
# 2                 2   10-Nov-15        12265   20-Oct-15          6
# 3                 3   10-Nov-15        12265   20-Oct-15          6
# 4                 4   10-Nov-15        12265   20-Oct-15          6
# ...             ...         ...          ...         ...        ...
# 4961773     4961773   11-Jun-15         1611   25-May-15          6
# 4961774     4961774   11-Jun-15         1611   25-May-15          6
# 4961775     4961775   11-Jun-15         1611   25-May-15          6
# 4961776     4961776   11-Jun-15         1611   25-May-15          6
# 4961777     4961777   11-Jun-15         1611   25-May-15          6
#
#          owner_indic  opened_dt last_paymt_dt  closed_dt reporting_dt  ...  \
# ...
